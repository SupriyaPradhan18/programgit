# %%
import pandas as pd

# %%
grades=pd.read_csv(r'C:\Users\91934\Downloads\ClassNotebooks\ClassNotebooks\grades.csv')

# %%
grades.shape
# Out:
# (2315, 13)

# %%
grades.head(11)
# Out:
#                               student_id  assignment1_grade  \
# 0   B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1   98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2   D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3   FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4   5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
# 5   D09000A0-827B-C0FF-3433-BF8FF286E15B          71.647278
# 6   3217BE3F-E4B0-C3B6-9F64-462456819CE4          87.498744
# 7   F1CB5AA1-B3DE-5460-FAFF-BE951FD38B5F          80.576090
# 8   C9D51293-BD58-F113-4167-A7C0BAFCB6E5          66.595568
# 9   E2C617C2-4654-622C-AB50-1550C4BE42A0          59.270882
# 10  ECFE7BB7-F618-A5B9-7A57-3BD2BCC0D880          45.838780
#
#            assignment1_submission  assignment2_grade  \
# 0   2015-11-02 06:55:34.282000000          83.030552
# 1   2015-11-29 14:57:44.429000000          86.290821
# 2   2016-01-09 05:36:02.389000000          85.512541
# ...

# %%
grades.tail(20)
# Out:
#                                 student_id  assignment1_grade  \
# 2295  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          38.788636
# 2296  25197F10-E9E9-4C50-63F8-6C896975AAE2          74.106685
# 2297  25197F10-E9E9-4C50-63F8-6C896975AAE2          91.192781
# 2298  DDE0526B-7DA4-80E8-C2A6-D097F3826029          68.571967
# 2299  247B105C-2067-A7AA-2CBE-B65278128C96          58.760286
# 2300  1F51E050-78F7-F270-1B90-ED1BC0376763          88.777948
# 2301  25197F10-E9E9-4C50-63F8-6C896975AAE2          74.260083
# 2302  2B806EF6-A590-1C00-F0C5-1469E3B2152E          62.048275
# 2303  DDE0526B-7DA4-80E8-C2A6-D097F3826029          97.215052
# 2304  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          65.123101
# 2305  5AB0D44C-86FF-2DE6-B096-B0F5D029E430          76.819524
# 2306  DDE0526B-7DA4-80E8-C2A6-D097F3826029          47.696703
# 2307  1F51E050-78F7-F270-1B90-ED1BC0376763          94.595758
# 2308  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          71.481182
# ...

# %%
grades.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# ...

# %%
grades.tail()
# Out:
#                                 student_id  assignment1_grade  \
# 2310  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          77.684611
# 2311  DE88902E-C7A7-E37A-CFA7-F2C8F2D219F2          75.367870
# 2312  EFDA9F93-D0C3-864F-B0F6-2E9AA3E05E31          73.269463
# 2313  1F51E050-78F7-F270-1B90-ED1BC0376763          87.268366
# 2314  DDE0526B-7DA4-80E8-C2A6-D097F3826029          80.318105
#
#              assignment1_submission  assignment2_grade  \
# 2310  2016-03-07 02:52:24.378000000          69.916150
# 2311  2015-11-29 02:43:27.932000000          59.934296
# 2312  2015-10-20 08:09:27.418000000          58.255570
# 2313  2016-04-03 09:04:51.646000000          87.268366
# 2314  2015-10-04 09:46:03.403000000          79.818105
#
#              assignment2_submission  assignment3_grade  \
# 2310  2016-03-11 22:02:39.161000000          69.916150
# 2311  2015-12-03 05:30:39.218000000          48.687437
# 2312  2015-11-18 19:07:06.930000000          58.955570
# ...

# %%
grades[grades.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [student_id, assignment1_grade, assignment1_submission, assignment2_grade, assignment2_submission, assignment3_grade, assignment3_submission, assignment4_grade, assignment4_submission, assignment5_grade, assignment5_submission, assignment6_grade, assignment6_submission]
# Index: []

# %%
 grades.columns
# Out:
# Index(['student_id', 'assignment1_grade', 'assignment1_submission',
#        'assignment2_grade', 'assignment2_submission', 'assignment3_grade',
#        'assignment3_submission', 'assignment4_grade', 'assignment4_submission',
#        'assignment5_grade', 'assignment5_submission', 'assignment6_grade',
#        'assignment6_submission'],
#       dtype='object')

# %%
grades[['assignment1_grade','assignment1_submission']]
# Out:
#       assignment1_grade         assignment1_submission
# 0             92.733946  2015-11-02 06:55:34.282000000
# 1             86.790821  2015-11-29 14:57:44.429000000
# 2             85.512541  2016-01-09 05:36:02.389000000
# 3             86.030665  2016-04-30 06:50:39.801000000
# 4             64.813800  2015-12-13 17:06:10.750000000
# ...                 ...                            ...
# 2310          77.684611  2016-03-07 02:52:24.378000000
# 2311          75.367870  2015-11-29 02:43:27.932000000
# 2312          73.269463  2015-10-20 08:09:27.418000000
# 2313          87.268366  2016-04-03 09:04:51.646000000
# 2314          80.318105  2015-10-04 09:46:03.403000000
#
# [2315 rows x 2 columns]

# %%
grades.dropna(axis=1,how='all',inplace=True)

# %%
grades.isnull()
# Out:
#       student_id  assignment1_grade  assignment1_submission  \
# 0          False              False                   False
# 1          False              False                   False
# 2          False              False                   False
# 3          False              False                   False
# 4          False              False                   False
# ...          ...                ...                     ...
# 2310       False              False                   False
# 2311       False              False                   False
# 2312       False              False                   False
# 2313       False              False                   False
# 2314       False              False                   False
#
#       assignment2_grade  assignment2_submission  assignment3_grade  \
# 0                 False                   False              False
# 1                 False                   False              False
# ...

# %%
grades.head()
# Out:
#                              student_id  assignment1_grade  \
# 0  B73F2C11-70F0-E37D-8B10-1D20AFED50B1          92.733946
# 1  98A0FAE0-A19A-13D2-4BB5-CFBFD94031D1          86.790821
# 2  D0F62040-CEB0-904C-F563-2F8620916C4E          85.512541
# 3  FFDF2B2C-F514-EF7F-6538-A6A53518E9DC          86.030665
# 4  5ECBEEB6-F1CE-80AE-3164-E45E99473FB4          64.813800
#
#           assignment1_submission  assignment2_grade  \
# 0  2015-11-02 06:55:34.282000000          83.030552
# 1  2015-11-29 14:57:44.429000000          86.290821
# 2  2016-01-09 05:36:02.389000000          85.512541
# 3  2016-04-30 06:50:39.801000000          68.824532
# 4  2015-12-13 17:06:10.750000000          51.491040
#
#           assignment2_submission  assignment3_grade  \
# 0  2015-11-09 02:22:58.938000000          67.164441
# 1  2015-12-06 17:41:18.449000000          69.772657
# 2  2016-01-09 06:39:44.416000000          68.410033
# 3  2016-04-30 17:20:38.727000000          61.942079
# ...

# %%
menu=['Tea','Coffee','Juice','Water']
pd.Series(menu)
# Out:
# 0       Tea
# 1    Coffee
# 2     Juice
# 3     Water
# dtype: object

# %%
seasons=['summer','winter','rainy','spring']
pd.Series(seasons)
# Out:
# 0    summer
# 1    winter
# 2     rainy
# 3    spring
# dtype: object

# %%
numbers=[20,98,77,66,34]
pd.Series(numbers)
# Out:
# 0    20
# 1    98
# 2    77
# 3    66
# 4    34
# dtype: int64

# %%
numbers=[3,5,6,None]
pd.Series(numbers)
# Out:
# 0    3.0
# 1    5.0
# 2    6.0
# 3    NaN
# dtype: float64

# %%
import numpy as np
np.nan==None
# Out:
# False

# %%
np.nan == np.nan
# Out:
# False

# %%
np.isnan(np.nan)
# Out:
# True

# %%
sports = {'Cricket': 'England',
          'Hockey': 'India',
          'Sumo': 'Japan',
          'Football': 'Australia'}
s = pd.Series(sports)
s
# Out:
# Cricket       England
# Hockey          India
# Sumo            Japan
# Football    Australia
# dtype: object

# %%
s.index[3]
# Out:
# 'Football'

# %%
type(s.index)
# Out:
# pandas.core.indexes.base.Index

# %%
s = pd.Series(['Parrot', 'Crow', 'Owl'], index=['Goa', 'Delhi', 'Pune'])
s
# Out:
# Goa      Parrot
# Delhi      Crow
# Pune        Owl
# dtype: object

# %%
sports = {'Cricket': 'England',
          'Hockey': 'India',
          'Sumo': 'Japan',
          'Football': 'Australia'}
s = pd.Series(sports,index=['Cricket','Hockey','Sumo'])
s
# Out:
# Cricket    England
# Hockey       India
# Sumo         Japan
# dtype: object

# %%
sports = {'Cricket': 'England',
          'Hockey': 'India',
          'Sumo': 'Japan',
          'Football': 'Australia'}
s = pd.Series(sports)
s
# Out:
# Cricket       England
# Hockey          India
# Sumo            Japan
# Football    Australia
# dtype: object

# %%
s.iloc[3]
# Out:
# 'Australia'

# %%
s.loc['Football']
# Out:
# 'Australia'

# %%
s[3]
# Out:
# 'Australia'

# %%
s['Cricket']
# Out:
# 'England'

# %%
sports = {99: 'Bhutan',
          100: 'Scotland',
          101: 'Japan',
          102: 'South Korea'}
s = pd.Series(sports)

# %%
s = pd.Series([100.00, 120.00, 101.00, 3.00])
s
# Out:
# 0    100.0
# 1    120.0
# 2    101.0
# 3      3.0
# dtype: float64

# %%
total = 0
for item in s:
    total+=item
print(total)
# Out:
# 324.0

# %%
s = pd.Series(np.random.randint(0,2000,10000))
s.head()
# Out:
# 0     398
# 1    1400
# 2    1162
# 3    1061
# 4    1274
# dtype: int32

# %%
len(s)
# Out:
# 10000

# %%
# %%timeit -n 100
summary = 0
for item in s:
    summary+=item
# Out:
# 1.65 ms ± 36.6 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n 100
summary = np.sum(s)
# Out:
# The slowest run took 7.52 times longer than the fastest. This could mean that an intermediate result is being cached.
# 169 µs ± 147 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
s+=2
s.head()
# Out:
# 0     404
# 1    1406
# 2    1168
# 3    1067
# 4    1280
# dtype: int32

# %%
# %%timeit -n 10
s = pd.Series(np.random.randint(0,1000,10000))
for label, value in s.iteritems():
    s.loc[label]= value+2
# Out:
# 451 ms ± 28.8 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
s = pd.Series([1, 2, 3])
s.loc['Animal'] = 'Cat'
s
# Out:
# 0           1
# 1           2
# 2           3
# Animal    Cat
# dtype: object

# %%
cars=pd.read_csv(r'C:\Users\91934\Downloads\ClassNotebooks\ClassNotebooks\cars.csv')

# %%
cars.shape
# Out:
# (53, 17)

# %%
cars.head(12)
# Out:
#     YEAR        Make                            Model        Size  (kW)  \
# 0   2012  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 1   2012      NISSAN                             LEAF    MID-SIZE    80
# 2   2013        FORD                   FOCUS ELECTRIC     COMPACT   107
# 3   2013  MITSUBISHI                           i-MiEV  SUBCOMPACT    49
# 4   2013      NISSAN                             LEAF    MID-SIZE    80
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET  TWO-SEATER    35
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE  TWO-SEATER    35
# 7   2013       TESLA         MODEL S (40 kWh battery)   FULL-SIZE   270
# 8   2013       TESLA         MODEL S (60 kWh battery)   FULL-SIZE   270
# 9   2013       TESLA         MODEL S (85 kWh battery)   FULL-SIZE   270
# 10  2013       TESLA              MODEL S PERFORMANCE   FULL-SIZE   310
# 11  2014   CHEVROLET                         SPARK EV  SUBCOMPACT   104
#
# ...

# %%
cars.tail()
# Out:
#     YEAR   Make                   Model            Size  (kW) Unnamed: 5 TYPE  \
# 48  2016  TESLA   MODEL S 90D (Refresh)       FULL-SIZE   386         A1    B
# 49  2016  TESLA       MODEL S P85D/P90D       FULL-SIZE   568         A1    B
# 50  2016  TESLA  MODEL S P90D (Refresh)       FULL-SIZE   568         A1    B
# 51  2016  TESLA             MODEL X 90D  SUV - STANDARD   386         A1    B
# 52  2016  TESLA            MODEL X P90D  SUV - STANDARD   568         A1    B
#
#     CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 48               20.8              19.7               20.3               2.3
# 49               23.4              21.5               22.5               2.6
# 50               22.9              21.0               22.1               2.6
# 51               23.2              22.2               22.7               2.6
# 52               23.6              23.3               23.5               2.7
#
# ...

# %%
cars[cars.isnull().any(axis=1)]
# Out:
#     YEAR        Make                            Model                   Size  \
# 0   2012  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 1   2012      NISSAN                             LEAF               MID-SIZE
# 2   2013        FORD                   FOCUS ELECTRIC                COMPACT
# 3   2013  MITSUBISHI                           i-MiEV             SUBCOMPACT
# 4   2013      NISSAN                             LEAF               MID-SIZE
# 5   2013       SMART  FORTWO ELECTRIC DRIVE CABRIOLET             TWO-SEATER
# 6   2013       SMART      FORTWO ELECTRIC DRIVE COUPE             TWO-SEATER
# 7   2013       TESLA         MODEL S (40 kWh battery)              FULL-SIZE
# 8   2013       TESLA         MODEL S (60 kWh battery)              FULL-SIZE
# 9   2013       TESLA         MODEL S (85 kWh battery)              FULL-SIZE
# 10  2013       TESLA              MODEL S PERFORMANCE              FULL-SIZE
# ...

# %%
cars.columns
# Out:
# Index(['YEAR', 'Make', 'Model', 'Size', '(kW)', 'Unnamed: 5', 'TYPE',
#        'CITY (kWh/100 km)', 'HWY (kWh/100 km)', 'COMB (kWh/100 km)',
#        'CITY (Le/100 km)', 'HWY (Le/100 km)', 'COMB (Le/100 km)', '(g/km)',
#        'RATING', '(km)', 'TIME (h)'],
#       dtype='object')

# %%
cars[['YEAR','CITY (kWh/100 km)']].agg(['min','mean','max'])
# Out:
#              YEAR  CITY (kWh/100 km)
# min   2012.000000           15.20000
# mean  2014.735849           19.64717
# max   2016.000000           23.90000

# %%
cars.dropna(axis=1,how='all',inplace=True)

# %%
cars.isnull()
# Out:
#      YEAR   Make  Model   Size   (kW)  Unnamed: 5   TYPE  CITY (kWh/100 km)  \
# 0   False  False  False  False  False       False  False              False
# 1   False  False  False  False  False       False  False              False
# 2   False  False  False  False  False       False  False              False
# 3   False  False  False  False  False       False  False              False
# 4   False  False  False  False  False       False  False              False
# 5   False  False  False  False  False       False  False              False
# 6   False  False  False  False  False       False  False              False
# 7   False  False  False  False  False       False  False              False
# 8   False  False  False  False  False       False  False              False
# 9   False  False  False  False  False       False  False              False
# 10  False  False  False  False  False       False  False              False
# ...

# %%
cars.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %%
cars.tail()
# Out:
#     YEAR   Make                   Model            Size  (kW) Unnamed: 5 TYPE  \
# 48  2016  TESLA   MODEL S 90D (Refresh)       FULL-SIZE   386         A1    B
# 49  2016  TESLA       MODEL S P85D/P90D       FULL-SIZE   568         A1    B
# 50  2016  TESLA  MODEL S P90D (Refresh)       FULL-SIZE   568         A1    B
# 51  2016  TESLA             MODEL X 90D  SUV - STANDARD   386         A1    B
# 52  2016  TESLA            MODEL X P90D  SUV - STANDARD   568         A1    B
#
#     CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 48               20.8              19.7               20.3               2.3
# 49               23.4              21.5               22.5               2.6
# 50               22.9              21.0               22.1               2.6
# 51               23.2              22.2               22.7               2.6
# 52               23.6              23.3               23.5               2.7
#
# ...

# %%
flights = pd.read_csv(r'C:\Users\91934\Downloads\ClassNotebooks\ClassNotebooks\flights.csv')
# Out:
# C:\Users\91934\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
flights.shape
# Out:
# (5819079, 31)

# %%
flights.head(10)
# Out:
#    YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0  2015      1    1            4      AS             98      N407AS
# 1  2015      1    1            4      AA           2336      N3KUAA
# 2  2015      1    1            4      US            840      N171US
# 3  2015      1    1            4      AA            258      N3HYAA
# 4  2015      1    1            4      AS            135      N527AS
# 5  2015      1    1            4      DL            806      N3730B
# 6  2015      1    1            4      NK            612      N635NK
# 7  2015      1    1            4      US           2013      N584UW
# 8  2015      1    1            4      AA           1112      N3LAAA
# 9  2015      1    1            4      DL           1173      N826DN
#
#   ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  ARRIVAL_TIME  \
# 0            ANC                 SEA                    5  ...         408.0
# ...

# %%
flights.tail()
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# 5819074            LAX                 BOS                 2359  ...
# 5819075            JFK                 PSE                 2359  ...
# 5819076            JFK                 SJU                 2359  ...
# 5819077            MCO                 SJU                 2359  ...
# 5819078            JFK                 BQN                 2359  ...
#
#          ARRIVAL_TIME  ARRIVAL_DELAY  DIVERTED  CANCELLED  \
# ...

# %%
flights[flights.isnull().any(axis=1)]
# Out:
#          YEAR  MONTH  DAY  DAY_OF_WEEK AIRLINE  FLIGHT_NUMBER TAIL_NUMBER  \
# 0        2015      1    1            4      AS             98      N407AS
# 1        2015      1    1            4      AA           2336      N3KUAA
# 2        2015      1    1            4      US            840      N171US
# 3        2015      1    1            4      AA            258      N3HYAA
# 4        2015      1    1            4      AS            135      N527AS
# ...       ...    ...  ...          ...     ...            ...         ...
# 5819074  2015     12   31            4      B6            688      N657JB
# 5819075  2015     12   31            4      B6            745      N828JB
# 5819076  2015     12   31            4      B6           1503      N913JB
# 5819077  2015     12   31            4      B6            333      N527JB
# 5819078  2015     12   31            4      B6            839      N534JB
#
#         ORIGIN_AIRPORT DESTINATION_AIRPORT  SCHEDULED_DEPARTURE  ...  \
# ...

# %%
flights.shape
# Out:
# (5819079, 31)

# %%
flights.isnull()
# Out:
#           YEAR  MONTH    DAY  DAY_OF_WEEK  AIRLINE  FLIGHT_NUMBER  \
# 0        False  False  False        False    False          False
# 1        False  False  False        False    False          False
# 2        False  False  False        False    False          False
# 3        False  False  False        False    False          False
# 4        False  False  False        False    False          False
# ...        ...    ...    ...          ...      ...            ...
# 5819074  False  False  False        False    False          False
# 5819075  False  False  False        False    False          False
# 5819076  False  False  False        False    False          False
# 5819077  False  False  False        False    False          False
# 5819078  False  False  False        False    False          False
#
#          TAIL_NUMBER  ORIGIN_AIRPORT  DESTINATION_AIRPORT  \
# 0              False           False                False
# ...
